# %% [markdown]
# # Dependencies

# %%
# %pip install keras
# Out:
# Requirement already satisfied: keras in d:\software\miniconda3\lib\site-packages (3.11.3)
# Requirement already satisfied: absl-py in d:\software\miniconda3\lib\site-packages (from keras) (2.2.2)
# Requirement already satisfied: numpy in d:\software\miniconda3\lib\site-packages (from keras) (2.0.2)
# Requirement already satisfied: rich in d:\software\miniconda3\lib\site-packages (from keras) (14.0.0)
# Requirement already satisfied: namex in d:\software\miniconda3\lib\site-packages (from keras) (0.0.9)
# Requirement already satisfied: h5py in d:\software\miniconda3\lib\site-packages (from keras) (3.13.0)
# Requirement already satisfied: optree in d:\software\miniconda3\lib\site-packages (from keras) (0.15.0)
# Requirement already satisfied: ml-dtypes in d:\software\miniconda3\lib\site-packages (from keras) (0.5.3)
# Requirement already satisfied: packaging in d:\software\miniconda3\lib\site-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in d:\software\miniconda3\lib\site-packages (from optree->keras) (4.14.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\software\miniconda3\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\software\miniconda3\lib\site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in d:\software\miniconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import keras
print(keras.__version__)
# Out:
# 3.9.2

# %%
# common tools
import sys
from pathlib import Path
sys.path.append(Path.cwd().parent.as_posix())
# print(sys.path)

from ml_tools.common import *

# %% [markdown]
# # Module

# %%
# inspect_submodules(keras)

# inspect_classes(keras.api.models)
# inspect_functions(keras.models)
