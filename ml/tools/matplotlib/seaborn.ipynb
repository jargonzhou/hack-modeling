# %% [markdown]
# # Dependencies

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~okeh (d:\software\miniconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~okeh (d:\software\miniconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~okeh (d:\software\miniconda3\Lib\site-packages)

# %%
# cleanup
# !pip uninstall seaborn -y

# %%
import seaborn as sns
sns.__version__
# Out:
# d:\software\miniconda3\Lib\site-packages\seaborn\_statistics.py:32: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 2.3.2)
#   from scipy.stats import gaussian_kde
# '0.13.2'
