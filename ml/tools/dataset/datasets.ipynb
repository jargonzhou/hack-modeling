# %% [markdown]
# # Datasets

# %% [markdown]
# # Kaggle

# %%
# https://github.com/Kaggle/kagglehub
# %pip install --upgrade kagglehub
# Out:
# Requirement already satisfied: kagglehub in d:\software\miniconda3\lib\site-packages (0.3.13)
# Requirement already satisfied: packaging in d:\software\miniconda3\lib\site-packages (from kagglehub) (24.1)
# Requirement already satisfied: pyyaml in d:\software\miniconda3\lib\site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in d:\software\miniconda3\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in d:\software\miniconda3\lib\site-packages (from kagglehub) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\software\miniconda3\lib\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\software\miniconda3\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\software\miniconda3\lib\site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\software\miniconda3\lib\site-packages (from requests->kagglehub) (2025.8.3)
# Requirement already satisfied: colorama in d:\software\miniconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub
import os

os.environ['KAGGLEHUB_CACHE'] = "./cache"

# %% [markdown]
# ## S&P 500 stock data
# * https://www.kaggle.com/datasets/camnugent/sandp500

# %%
# Download latest version
path = kagglehub.dataset_download("camnugent/sandp500")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/camnugent/sandp500?dataset_version_number=4...
# 100%|██████████| 19.3M/19.3M [00:22<00:00, 906kB/s]
# Extracting files...
# Path to dataset files: ./cache\datasets\camnugent\sandp500\versions\4

# %% [markdown]
# ## Flower Color Images
# * https://www.kaggle.com/datasets/olgabelitskaya/flower-color-images/data

# %%
path = kagglehub.dataset_download("olgabelitskaya/flower-color-images")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/olgabelitskaya/flower-color-images?dataset_version_number=7...
# 100%|██████████| 50.1M/50.1M [00:57<00:00, 918kB/s]
# Extracting files...
# Path to dataset files: ./cache\datasets\olgabelitskaya\flower-color-images\versions\7

# %% [markdown]
# # Practical Statistics for Data Scientists
# - https://github.com/gedeck/practical-statistics-for-data-scientists/tree/master/data

# %% [markdown]
# # ISL: An Introduction to Statistical Learning
